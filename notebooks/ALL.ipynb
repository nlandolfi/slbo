# %%
import utils2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # HCFB

# %%
r, lines = utils2.load(698208, reload=False)
r.details()
print(f"First Stage took {r.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {r.warms[1].duration_in_seconds()/60} minutes")
# Out:
# Skipping Load
# Reading lines
# Read lines
# time data '2019-05-10T20:00:53' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [0, 20, 887.0023183663995, 6.106294201742409, 0.24225834012031555, 1.187330961227417, 3.4188055992126465], 'caller': 'main2.py:226', 'time': '2019-05-10T20:00:53'}
# Run:
# 	100 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 22.247128784656525 minutes

# %%
print(f"Mean over last 20: {np.mean(r.post_slbo_real_eval_means[-20:])}")
print(f"Max achieved: {np.max(r.post_slbo_real_eval_means)}")
r.plot_post_slbo_evals()
# Out:
# Mean over last 20: 607.6282004564467
# Max achieved: 737.4750209097966

# %%
HCFBevals = [699943, 699944, 699945, 699946, 699947, 699948, 699949, 699950, 699951, 699952, 699953, 699954, 699955, 699956, 699957, 699958, 699959, 699960, 699961, 699962, 699963, 699964, 699965, 699966, 699967, 699968, 699969, 699970, 699971, 699972, 699973, 699974, 699975, 699976, 699977, 699978, 699979, 699980, 699981, 699982]

# %%
HCFBeval_runs = [utils2.load(job, reload=False, verbose=False) for job in HCFBevals]
nums = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in HCFBeval_runs]
nums = np.array(nums)
plt.errorbar(np.arange(5), np.mean(nums, axis=0), yerr=np.std(nums, axis=0))
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # HCP

# %%
r, lines = utils2.load(698209, reload=False)
r.details()
print(f"First Stage took {r.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {r.warms[1].duration_in_seconds()/60} minutes")
# Out:
# Skipping Load
# Reading lines
# Read lines
# Run:
# 	100 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 22.35392761627833 minutes

# %%
print(f"Mean over last 20: {np.mean(r.post_slbo_real_eval_means[-20:])}")
print(f"Max achieved: {np.max(r.post_slbo_real_eval_means)}")
r.plot_post_slbo_evals()
# Out:
# Mean over last 20: -20.87112065617695
# Max achieved: -2.1510670060369295

# %%
HCPevals = [699983, 699984, 699985, 699986, 699987, 699988, 699989, 699990, 699991, 699992, 699993, 699994, 699995, 699996, 699997, 699998, 699999, 700000, 700001, 700002, 700003, 700004, 700005, 700006, 700007, 700008, 700009, 700010, 700011, 700012, 700013, 700014, 700015, 700016, 700017, 700018, 700019, 700020, 700021, 700022]

# %%
HCPeval_runs = [utils2.load(job, reload=False, verbose=False) for job in HCPevals]
nums = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in HCPeval_runs]
nums = np.array(nums)
plt.errorbar(np.arange(5), np.mean(nums, axis=0), yerr=np.std(nums, axis=0))
# Out:
# time data '2019-05-12T21:26:43' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [29, 20, -6.49953021563275, 0.3153113427119442, 0.03978521749377251, 0.11906307190656662, 0.0027501003351062536], 'caller': 'main2.py:414', 'time': '2019-05-12T21:26:43'}
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # HCF

# %%
r, lines = utils2.load(698210, reload=False)
r.details()
print(f"First Stage took {r.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {r.warms[1].duration_in_seconds()/60} minutes")
# Out:
# Skipping Load
# Reading lines
# Read lines
# Run:
# 	100 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 22.481904300053916 minutes

# %%
print(f"Mean over last 20: {np.mean(r.post_slbo_real_eval_means[-20:])}")
print(f"Max achieved: {np.max(r.post_slbo_real_eval_means)}")
r.plot_post_slbo_evals()
# Out:
# Mean over last 20: -23.49409743592853
# Max achieved: -3.207315363683365

# %%
HCFevals = [700023, 700024, 700025, 700026, 700027, 700028, 700029, 700030, 700031, 700032, 700033, 700034, 700035, 700036, 700037, 700038, 700039, 700040, 700041, 700042, 700043, 700044, 700045, 700046, 700047, 700048, 700049, 700050, 700051, 700052, 700053, 700054, 700055, 700056, 700057, 700058, 700059, 700060, 700061, 700062]

# %%
HCFeval_runs = [utils2.load(job, reload=False, verbose=False) for job in HCFevals]
nums = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in HCFeval_runs]
nums = np.array(nums)
plt.errorbar(np.arange(5), np.mean(nums, axis=0), yerr=np.std(nums, axis=0))
# Out:
# time data '2019-05-12T22:18:29' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [11, 20, -4.831385035864919, 0.2669860078383912, 0.05012540891766548, 0.09628941863775253, 0.0011382859665900469], 'caller': 'main2.py:414', 'time': '2019-05-12T22:18:29'}
# time data '2019-05-13T00:14:38' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [36, 20, -2.595461505259329, 0.263513354036506, 0.029130667448043823, 0.08303836733102798, 0.00937177799642086], 'caller': 'main2.py:414', 'time': '2019-05-13T00:14:38'}
# <ErrorbarContainer object of 3 artists>

# %%
HCF50evals = [703222, 703223, 703224, 703225, 703226, 703227, 703228, 703229, 703230, 703231, 703232, 703233, 703234, 703235, 703236, 703237, 703238, 703239, 703240, 703241, 703242, 703243, 703244, 703245, 703246, 703247, 703248, 703249, 703250, 703251, 703252, 703253, 703254, 703255, 703256, 703257, 703258, 703259, 703260, 703261]
HCF50eval_runs = [utils2.load(job, reload=False, verbose=False) for job in HCF50evals]
nums50 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in HCF50eval_runs]
nums50 = np.array(nums50)

# %%
plt.errorbar(np.arange(5), np.mean(nums, axis=0), yerr=np.std(nums, axis=0), label="100 iters")
plt.errorbar(np.arange(5)+0.05, np.mean(nums50, axis=0), yerr=np.std(nums50, axis=0), label="50 iters")
plt.legend()

# %% [markdown]
# # AFB

# %%
r, lines = utils2.load(698211, reload=False)
r.details()
print(f"First Stage took {r.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {r.warms[1].duration_in_seconds()/60} minutes")
# Out:
# Skipping Load
# Reading lines
# Read lines
# Run:
# 	100 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 24.042950185139976 minutes

# %%
print(f"Mean over last 20: {np.mean(r.post_slbo_real_eval_means[-20:])}")
print(f"Max achieved: {np.max(r.post_slbo_real_eval_means)}")
r.plot_post_slbo_evals()
# Out:
# Mean over last 20: 821.5731234559371
# Max achieved: 943.7030973811695

# %%
AFBevals = [700063, 700064, 700065, 700066, 700067, 700068, 700069, 700070, 700071, 700072, 700073, 700074, 700075, 700076, 700077, 700078, 700079, 700080, 700081, 700082, 700083, 700084, 700085, 700086, 700087, 700088, 700089, 700090, 700091, 700092, 700093, 700094, 700095, 700096, 700097, 700098, 700099, 700100, 700101, 700102]

# %%
AFBeval_runs = [utils2.load(job, reload=False, verbose=False) for job in AFBevals]
nums = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in AFBeval_runs]
nums = np.array(nums)
plt.errorbar(np.arange(5), np.mean(nums, axis=0), yerr=np.std(nums, axis=0))
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # AP

# %%
r, lines = utils2.load(698212, reload=False)
r.details()
print(f"First Stage took {r.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {r.warms[1].duration_in_seconds()/60} minutes")
# Out:
# Skipping Load
# Reading lines
# Read lines
# Run:
# 	100 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 24.15884381532669 minutes

# %%
print(f"Mean over last 20: {np.mean(r.post_slbo_real_eval_means[-20:])}")
print(f"Max achieved: {np.max(r.post_slbo_real_eval_means)}")
r.plot_post_slbo_evals()
# Out:
# Mean over last 20: 183.628510149543
# Max achieved: 205.70367074461439

# %%
APevals = [700103, 700104, 700105, 700106, 700107, 700108, 700109, 700110, 700111, 700112, 700113, 700114, 700115, 700116, 700117, 700118, 700119, 700120, 700121, 700122, 700123, 700124, 700125, 700126, 700127, 700128, 700129, 700130, 700131, 700132, 700133, 700134, 700135, 700136, 700137, 700138, 700139, 700140, 700141, 700142]

# %%
APeval_runs = [utils2.load(job, reload=False, verbose=False) for job in APevals]
nums = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in APeval_runs]
nums = np.array(nums)
plt.errorbar(np.arange(5), np.mean(nums, axis=0), yerr=np.std(nums, axis=0))
# Out:
# time data '2019-05-13T00:37:20' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [24, 20, 204.0382577094865, 0.06987186235675277, 0.23576050996780396, 0.30318912863731384, 0.004341847263276577], 'caller': 'main2.py:259', 'time': '2019-05-13T00:37:20'}
# time data '2019-05-13T02:18:14' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [34, 20, 207.0967093972053, 0.15693858961360965, 0.07259435951709747, 0.19009599089622498, 0.0009727921569719911], 'caller': 'main2.py:414', 'time': '2019-05-13T02:18:14'}
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # AF

# %%
r, lines = utils2.load(698213, reload=False)
r.details()
print(f"First Stage took {r.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {r.warms[1].duration_in_seconds()/60} minutes")
# Out:
# Skipping Load
# Reading lines
# Read lines
# Run:
# 	100 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 25.13242328564326 minutes

# %%
print(f"Mean over last 20: {np.mean(r.post_slbo_real_eval_means[-20:])}")
print(f"Max achieved: {np.max(r.post_slbo_real_eval_means)}")
r.plot_post_slbo_evals()
# Out:
# Mean over last 20: 180.05669673786014
# Max achieved: 202.14546661304513

# %%
AFevals = [700143, 700144, 700145, 700146, 700147, 700148, 700149, 700150, 700151, 700152, 700153, 700154, 700155, 700156, 700157, 700158, 700159, 700160, 700161, 700162, 700163, 700164, 700165, 700166, 700167, 700168, 700169, 700170, 700171, 700172, 700173, 700174, 700175, 700176, 700177, 700178, 700179, 700180, 700181, 700182]

# %%
AFeval_runs = [utils2.load(job, reload=False, verbose=False) for job in AFevals]
nums = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in AFeval_runs]
nums = np.array(nums)
plt.errorbar(np.arange(5), np.mean(nums, axis=0), yerr=np.std(nums, axis=0))
# Out:
# time data '2019-05-13T04:19:06' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [18, 20, 183.9593912583262, 0.6057099149086652, 0.3694242835044861, 0.537971019744873, 0.15204167366027832], 'caller': 'main2.py:259', 'time': '2019-05-13T04:19:06'}
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # AD

# %%
r, lines = utils2.load(698356, reload=False)
r.details()
print(f"First Stage took {r.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {r.warms[1].duration_in_seconds()/60} minutes")
# Out:
# Skipping Load
# Reading lines
# Read lines
# Run:
# 	100 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 23.681219085057577 minutes

# %%
print(f"Mean over last 20: {np.mean(r.post_slbo_real_eval_means[-20:])}")
print(f"Max achieved: {np.max(r.post_slbo_real_eval_means)}")
r.plot_post_slbo_evals()
# Out:
# Mean over last 20: 272.04342613932624
# Max achieved: 388.856023497

# %%
ADevals = [702830, 702831, 702832, 702833, 702834, 702835, 702836, 702837, 702838, 702839, 702840, 702841, 702842, 702843, 702844, 702845, 702846, 702847, 702848, 702849, 702850, 702851, 702852, 702853, 702854, 702855, 702856, 702857, 702858, 702859, 702860, 702861, 702862, 702863, 702864, 702865, 702866, 702867, 702868, 702869]

# %%
ADeval_runs = [utils2.load(job, reload=False, verbose=False) for job in ADevals]
nums = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in ADeval_runs]
nums = np.array(nums)
plt.errorbar(np.arange(5), np.mean(nums, axis=0), yerr=np.std(nums, axis=0))
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # HUFB

# %%
r, lines = utils2.load(698976, reload=False)
r.details()
print(f"First Stage took {r.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {r.warms[1].duration_in_seconds()/60} minutes")
# Out:
# Skipping Load
# Reading lines
# Read lines
# time data '2019-05-12T02:27:18' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [10, 31, 84.43485692160077, 3.6949302677576994, 1.0505638122558594, 0.45846059918403625, 7.874422073364258], 'caller': 'main2.py:226', 'time': '2019-05-12T02:27:18'}
# Run:
# 	100 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 19.78586258093516 minutes

# %%
print(f"Mean over last 20: {np.mean(r.post_slbo_real_eval_means[-20:])}")
print(f"Max achieved: {np.max(r.post_slbo_real_eval_means)}")
r.plot_post_slbo_evals()
# Out:
# Mean over last 20: 139.95324584060083
# Max achieved: 237.3229039837244

# %%
HUFBevals = [700143, 700144, 700145, 700146, 700147, 700148, 700149, 700150, 700151, 700152, 700153, 700154, 700155, 700156, 700157, 700158, 700159, 700160, 700161, 700162, 700163, 700164, 700165, 700166, 700167, 700168, 700169, 700170, 700171, 700172, 700173, 700174, 700175, 700176, 700177, 700178, 700179, 700180, 700181, 700182]

# %%
HUFBeval_runs = [utils2.load(job, reload=False, verbose=False) for job in HUFBevals]
nums = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in HUFBeval_runs]
nums = np.array(nums)
plt.errorbar(np.arange(5), np.mean(nums, axis=0), yerr=np.std(nums, axis=0))
# Out:
# time data '2019-05-13T04:19:06' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [18, 20, 183.9593912583262, 0.6057099149086652, 0.3694242835044861, 0.537971019744873, 0.15204167366027832], 'caller': 'main2.py:259', 'time': '2019-05-13T04:19:06'}
# <ErrorbarContainer object of 3 artists>
