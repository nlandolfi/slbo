# %%
import utils2
import numpy as np
import matplotlib.pyplot as plt

# %%
dropMeanRun, _ = utils2.load(704432, reload=True)
dropMeanRun.details()
print(f"First Stage took {dropMeanRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {dropMeanRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {dropMeanRun.n_skips}")
print(f"Performed: {len(dropMeanRun.tasks) - dropMeanRun.n_skips}")
plt.plot(dropMeanRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# time data '2019-05-16T11:45:34' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [19, 20, 382.7184106177994, 1.5397185239480213, 0.27746492624282837, 0.5296092629432678, 0.3561021089553833], 'caller': 'main2.py:262', 'time': '2019-05-16T11:45:34'}
# Run:
# 	119 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 22.534508049488068 minutes
# Skips: 58
# Performed: 61

# %%
shadowStateErrorRun, _ = utils2.load(704436, reload=True)
shadowStateErrorRun.details()
print(f"First Stage took {shadowStateErrorRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {shadowStateErrorRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {shadowStateErrorRun.n_skips}")
print(f"Performed: {len(shadowStateErrorRun.tasks) - shadowStateErrorRun.n_skips}")
plt.plot(shadowStateErrorRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	120 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 22.564170118172964 minutes
# Skips: 54
# Performed: 66

# %%
realRewardDiffRun, _ = utils2.load(704441, reload=True)
realRewardDiffRun.details()
print(f"First Stage took {realRewardDiffRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {realRewardDiffRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {realRewardDiffRun.n_skips}")
print(f"Performed: {len(realRewardDiffRun.tasks) - realRewardDiffRun.n_skips}")
plt.plot(realRewardDiffRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	119 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 22.613082134723662 minutes
# Skips: 61
# Performed: 58

# %%
realStateErrRun, _ = utils2.load(704442, reload=True)
realStateErrRun.details()
print(f"First Stage took {realStateErrRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {realStateErrRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {realStateErrRun.n_skips}")
print(f"Performed: {len(realStateErrRun.tasks) - realStateErrRun.n_skips}")
plt.plot(realStateErrRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [1, 20, 343.40139500662707, 1.2788395385069864, 0.24610081315040588, 0.5375819802284241, 0.4915466010570526], 'caller': 'main2.py:416', 'time': '2019-05-17T19:00:28'}

# %%
AD50eval_runs = [utils2.load(job, reload=True, verbose=False) for job in AD50evals]
AD50 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in AD50eval_runs]

# %%
AD100eval_runs = [utils2.load(job, reload=True, verbose=False) for job in AD100evals]
AD100 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in AD100eval_runs]

# %%
ADDM30eval_runs = [utils2.load(job, reload=True, verbose=False) for job in ADDM30evals]
ADDM30 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in ADDM30eval_runs]

# %%
ADSSE30eval_runs = [utils2.load(job, reload=True, verbose=False) for job in ADSSE30evals]
ADSSE30 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in ADSSE30eval_runs]
# Out:
# time data '2019-05-17T16:51:44' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [0, 20, 124.82770365571557, 3.1199172948464384, 1.0606471300125122, 0.6238464117050171, 132.96585083007812], 'caller': 'main2.py:262', 'time': '2019-05-17T16:51:44'}

# %%
ADRSE30eval_runs = [utils2.load(job, reload=True, verbose=False) for job in ADRSE30evals]
ADRSE30 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in ADRSE30eval_runs]

# %%
ADRRD30eval_runs = [utils2.load(job, reload=True, verbose=False) for job in ADRRD30evals]
ADRRD30 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in ADRRD30eval_runs]

# %%
plt.errorbar(np.arange(5)+0.1, np.mean(AD100, axis=0), yerr=np.std(AD100, axis=0), label="AD100")
plt.errorbar(np.arange(5)+0.15, np.mean(AD50, axis=0), yerr=np.std(AD50, axis=0), label="AD50")
plt.errorbar(np.arange(5)+0.2, np.mean(AD30, axis=0), yerr=np.std(AD30, axis=0), label="AD30")
plt.errorbar(np.arange(5)+0.25, np.mean(ADDM30, axis=0), yerr=np.std(ADDM30, axis=0), label="ADDM30")
plt.errorbar(np.arange(5)+0.3, np.mean(ADSSE30, axis=0), yerr=np.std(ADSSE30, axis=0), label="ADSSE30")
plt.errorbar(np.arange(5)+0.35, np.mean(ADRSE30, axis=0), yerr=np.std(ADRSE30, axis=0), label="ADRSE30")
plt.errorbar(np.arange(5)+0.4, np.mean(ADRRD30, axis=0), yerr=np.std(ADRRD30, axis=0), label="ADRRD30")
plt.axhline(y=275)
plt.legend()
