# %%
import utils2
import numpy as np
import matplotlib.pyplot as plt

# %%
dropMeanRun, _ = utils2.load(704427, reload=True)
dropMeanRun.details()
print(f"First Stage took {dropMeanRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {dropMeanRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {dropMeanRun.n_skips}")
print(f"Performed: {len(dropMeanRun.tasks) - dropMeanRun.n_skips}")
plt.plot(dropMeanRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	130 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 20.992538567384084 minutes
# Skips: 65
# Performed: 65

# %%
shadowStateErrorRun, _ = utils2.load(704435, reload=True)
shadowStateErrorRun.details()
print(f"First Stage took {shadowStateErrorRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {shadowStateErrorRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {shadowStateErrorRun.n_skips}")
print(f"Performed: {len(shadowStateErrorRun.tasks) - shadowStateErrorRun.n_skips}")
plt.plot(shadowStateErrorRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	130 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 20.90289373397827 minutes
# Skips: 82
# Performed: 48

# %%
realRewardDiffRun, _ = utils2.load(704429, reload=True)
realRewardDiffRun.details()
print(f"First Stage took {realRewardDiffRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {realRewardDiffRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {realRewardDiffRun.n_skips}")
print(f"Performed: {len(realRewardDiffRun.tasks) - realRewardDiffRun.n_skips}")
plt.plot(realRewardDiffRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	154 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 17.740301183859508 minutes
# Skips: 74
# Performed: 80

# %%
realStateErrRun, _ = utils2.load(704431, reload=True)
realStateErrRun.details()
print(f"First Stage took {realStateErrRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {realStateErrRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {realStateErrRun.n_skips}")
print(f"Performed: {len(realStateErrRun.tasks) - realStateErrRun.n_skips}")
plt.plot(realStateErrRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	162 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 16.873594919840496 minutes
HCFSSE30 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in HCFSSE30eval_runs]

# %%
HCFRSE30eval_runs = [utils2.load(job, reload=False, verbose=False) for job in HCFRSE30evals]
HCFRSE30 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in HCFRSE30eval_runs]

# %%
HCFRRD30eval_runs = [utils2.load(job, reload=False, verbose=False) for job in HCFRRD30evals]
HCFRRD30 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in HCFDM30eval_runs]

# %%
HCF100eval_runs = [utils2.load(job, reload=False, verbose=False) for job in HCF100evals]
HCF100 = [np.append(t[0].slbos[0].episode_real_mean_evals, t[0].post_slbo_real_eval_means[0]) for t in HCF100eval_runs]
# Out:
# time data '2019-05-12T22:18:29' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [11, 20, -4.831385035864919, 0.2669860078383912, 0.05012540891766548, 0.09628941863775253, 0.0011382859665900469], 'caller': 'main2.py:414', 'time': '2019-05-12T22:18:29'}
# time data '2019-05-13T00:14:38' does not match format '%Y-%m-%dT%H:%M:%S.%f'
# {'level': 'info', 'fmt': '[TRPO] # %d: n_episodes = %d, returns: {mean = %.0f, std = %.0f}, dist std = %.10f, dist mean = %.10f, vf_loss = %.3f', 'args': [36, 20, -2.595461505259329, 0.263513354036506, 0.029130667448043823, 0.08303836733102798, 0.00937177799642086], 'caller': 'main2.py:414', 'time': '2019-05-13T00:14:38'}

# %%
plt.errorbar(np.arange(5)+0.1, np.mean(HCF100, axis=0), yerr=np.std(HCF100, axis=0), label="HCF100")
plt.errorbar(np.arange(5)+0.1, np.mean(HCF30, axis=0), yerr=np.std(HCF30, axis=0), label="HCF30")
plt.errorbar(np.arange(5)+0.15, np.mean(HCFDM30, axis=0), yerr=np.std(HCFDM30, axis=0), label="HCFDM30")
plt.errorbar(np.arange(5)+0.2, np.mean(HCFSSE30, axis=0), yerr=np.std(HCFSSE30, axis=0), label="HCFSSE30")
plt.errorbar(np.arange(5)+0.25, np.mean(HCFRSE30, axis=0), yerr=np.std(HCFRSE30, axis=0), label="HCFRSE30")
plt.errorbar(np.arange(5)+0.3, np.mean(HCFRRD30, axis=0), yerr=np.std(HCFRRD30, axis=0), label="HCFRRD30")
plt.legend()
