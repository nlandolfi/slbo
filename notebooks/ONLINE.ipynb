# %%
import utils2
import numpy as np
import matplotlib.pyplot as plt

# %%
dropMeanRun, _ = utils2.load(700245, reload=True)
dropMeanRun.details()
print(f"First Stage took {dropMeanRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {dropMeanRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {dropMeanRun.n_skips}")
plt.scatter(np.arange(len(dropMeanRun.skip_metrics)), dropMeanRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	71 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 26.59887431462606 minutes
# Skips: 33

# %%
dropVarianceRun, _ = utils2.load(700246, reload=True)
dropVarianceRun.details()
print(f"First Stage took {dropMeanRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {dropMeanRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {dropVarianceRun.n_skips}")
plt.plot(dropVarianceRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	69 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 26.59887431462606 minutes
# Skips: 27

# %%
shadowRewardVarianceRun, _ = utils2.load(699167, reload=True)
shadowRewardVarianceRun.details()
print(f"First Stage took {shadowRewardVarianceRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {shadowRewardVarianceRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {shadowRewardVarianceRun.n_skips}")
plt.plot(shadowRewardVarianceRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	98 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 31.357054297129313 minutes
# Skips: 52

# %%
shadowStateErrorRun, _ = utils2.load(699932, reload=True)
shadowStateErrorRun.details()
print(f"First Stage took {shadowStateErrorRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {shadowStateErrorRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {shadowStateErrorRun.n_skips}")
plt.plot(shadowStateErrorRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	70 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 25.54032776753108 minutes
# Skips: 39

# %%
shadowStateVarianceRun, _ = utils2.load(699933, reload=True)
shadowStateVarianceRun.details()
print(f"First Stage took {shadowStateVarianceRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {shadowStateVarianceRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {shadowStateVarianceRun.n_skips}")
plt.plot(shadowStateVarianceRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	86 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 22.277625731627147 minutes
# Skips: 52

# %%
realRewardDiffRun, _ = utils2.load(699934, reload=True)
realRewardDiffRun.details()
print(f"First Stage took {realRewardDiffRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {realRewardDiffRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {realRewardDiffRun.n_skips}")
plt.plot(realRewardDiffRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	72 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 25.42983874877294 minutes
# Skips: 32

# %%
realStateErrRun, _ = utils2.load(699935, reload=True)
realStateErrRun.details()
print(f"First Stage took {realStateErrRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {realStateErrRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {realStateErrRun.n_skips}")
plt.plot(realStateErrRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	73 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 25.120644950866698 minutes
# Skips: 37

# %%
realStateVarianceRun, _ = utils2.load(699937, reload=True)
realStateVarianceRun.details()
print(f"First Stage took {realStateVarianceRun.slbos[0].stages[0].duration_in_seconds()/60} minutes")
print(f"First Warmup took {realStateVarianceRun.warms[1].duration_in_seconds()/60} minutes")
print(f"Skips: {realStateVarianceRun.n_skips}")
plt.plot(realStateVarianceRun.skip_metrics)
# Out:
# Loading log file
# Loaded log file
# Reading lines
# Read lines
# Run:
# 	70 Tasks so far
# First Stage took 0.0 minutes
# First Warmup took 25.88829978307088 minutes
# Skips: 37
